# %% [markdown]
# # 03 — Structural Break Visualization
#
# **Purpose.** Visualize Chow F-statistic series, Bai-Perron break dates with 95% CIs, and CUSUM plots for each pre-registered event in `config/events.yml`.
#
# **Author / date.** Research team — fill in.
#
# **Inputs.**
# - `reports/panels/master_daily.parquet`
# - `reports/tables/breaks/*.csv` (produced by agent 03 — quant methods)
# - `config/events.yml`
#
# **Outputs.** `reports/figures/f05_chow_YYYY-MM-DD.{png,pdf}`, `reports/figures/f06_bai_perron_YYYY-MM-DD.{png,pdf}`.
#
# **Plan section.** §11.4, §15.
#
# **Confidence.** Blocked on the structural-break tables from agent 03.

# %%
from __future__ import annotations

import sys
from pathlib import Path

_ROOT = Path.cwd().resolve()
while _ROOT != _ROOT.parent and not (_ROOT / "pyproject.toml").exists():
    _ROOT = _ROOT.parent
if str(_ROOT) not in sys.path:
    sys.path.insert(0, str(_ROOT))

from config.paths import TABLES_DIR, FIGURES_DIR, EVENTS_YML  # noqa: E402

BREAKS_DIR = TABLES_DIR / 'breaks'
print('breaks dir:', BREAKS_DIR)
print('exists:', BREAKS_DIR.exists())

# %%
# Placeholder. Full plotting is the responsibility of agent 04 (viz). This
# notebook is for exploratory visualization during development; final figures
# must come from src/cqresearch/viz/figure_templates.py using the figure-template
# skill.
print('Awaiting reports/tables/breaks/*.csv from agent 03.')
